# %% [markdown]
# ## Dram Item Cleaning
#
# This notebook attempts to map Dram Shop items on to the actual beverage along with the producer and additional information. For instance, we want to map `Ommegang - Rare Vos Belgian Style Amber Ale  - 6.5% ABV 20 IBU` to `ommegang` (the producer), `Rare Vos Belgian Style Amber Ale` (the beer), and `6.5% ABV 20 IBU` (the additional information).
#
# This is hard! The items are manually entered so we have things like abbreviations, misspellings, odd orderings, etc.
#
#
# We'll start by pulling in the items and their categories, which will be our starting point.

# %%
import os
import re
import datetime 
from collections import Counter
import requests
import time

import pandas as pd
import numpy as np
import pandas_gbq
import janitor

# Do our imports for the code
from google.cloud import bigquery
from google.oauth2 import service_account

# %% [markdown]
# ### GBQ Set Up
#
# In this next section we connect to our GBQ project and list the data sets inside to test the connection.

# %%
# These first two values will be different on your machine. 
service_path = "/Users/chandler/Dropbox/Teaching/"
service_file = 'umt-msba-037daf11ee16.json' # change this to your authentication information  
gbq_proj_id = 'umt-msba' # change this to your project. 

# And this should stay the same. 
private_key =service_path + service_file

# Now we pass in our credentials so that Python has permission to access our project.
credentials = service_account.Credentials.from_service_account_file(service_path + service_file)

# And finally we establish our connection
client = bigquery.Client(credentials = credentials, project=gbq_proj_id)

for item in client.list_datasets() : 
    print(item.full_dataset_id)
# Out:
# umt-msba:dram_shop
# umt-msba:transactions
# umt-msba:wedge_example
# umt-msba:wedge_transactions

# %% [markdown]
# ### Pulling data from GBQ
#
# Let's get the items and their categories from our Dram data.

# %%
query = """
    SELECT *
    FROM `umt-msba.dram_shop.brewery_data`
"""

brewery_data = client.query(query).to_dataframe()

# %%
query = """
    SELECT item,
           category, 
           price_point_name, 
           EXTRACT(YEAR FROM CAST(date as DATE)) AS year,
           SUM(gross_sales) AS gross_sales
    FROM `umt-msba.dram_shop.dram_items_2022*`
    GROUP BY item, category, price_point_name, year
"""

item_info = client.query(query).to_dataframe()

# %%
item_info.category.value_counts()
# Out:
# F-IPA Draught                  579
# C-IPA Draught                  559
# F-Lagers/Pils/Wheat Draught    240
# C-Lagers/Pils/Wheat Draught    237
# F-Seasonal                     234
#                               ...
# Wine - Bottled                   1
# Double K                         1
# zCider - Draught                 1
# Big Beer - Bottled               1
# zIPA - Draught                   1
# Name: category, Length: 81, dtype: int64

# %%
item_info.price_point_name.value_counts()
# Out:
# Half Glass                   690
# 64 oz                        450
# Pint                         306
# To-Go                        297
# 32 oz                        250
#                             ...
# XXL                            1
# Flight of 3                    1
# Glacier brewing root beer      1
# White Wine Glass 12oz          1
# Gray                           1
# Name: price_point_name, Length: 180, dtype: int64

# %% [markdown]
# ### Investigating Categories
#
# Let's take a look at the categories and do some work to clean them up (mostly across locations)

# %%
# Going to assume lowercase

cat_prefix = re.compile(r"[fc] ?- ?")
cat_suffix = re.compile(r" -? ?(draught|bottled|bottles|cans)")

# %%
def clean_cat(cat) : 
    
    """
        Given a raw category from Dram, return a clean category. Usually this involves 
        removing the prefix and Draught/bottled at the end.
    
    """
    clean_cat = cat.lower()

    clean_cat = cat_prefix.sub("",clean_cat)
    clean_cat = cat_suffix.sub("",clean_cat)
    
    return(clean_cat)

# %%
item_info['clean_category'] = item_info['category'].map(clean_cat)

# %%
item_info.head()
# Out:
#                    item        category price_point_name  year  gross_sales  \
# 0              LA CROIX  Soda - Bottled             HERE  2022        118.0
# 1         Potato CHIPS!          Snacks              Bag  2022       2620.0
# 2       Stretch Sticker           Misc.          Regular  2022         56.0
# 3  Roadhouse Wilson IPA   IPA - Bottled           to Go!  2022         50.0
# 4  Sticker Black Bottom           Misc.          Regular  2022         49.0
#
#   clean_category
# 0           soda
# 1         snacks
# 2          misc.
# 3            ipa
# 4          misc.

# %%
(item_info.groupby('clean_category').
    sum('gross_sales').reset_index().
    sort_values('gross_sales',ignore_index=True,ascending=False))
# Out:
#             clean_category     year  gross_sales
# 0                      ipa  2553786    219034.75
# 1        lagers/pils/wheat  1209156    104918.00
# 2                     wine   525720     59280.25
# 3                    cider   798690     49871.00
# 4                     sour   721854     41824.75
# 5                 seasonal   837108     31086.00
# 6             porter/stout   531786     28900.00
# 7             ambers/pales   487302     24430.25
# 8               amber/pale   374070     20286.00
# 9                 kombucha    12132     16938.50
# 10                 belgian   305322     15983.75
# 11           btg features!    78858     10450.50
# 12                    none    34374      9684.61
# 13  wine packages/tastings   141540      9543.25
# 14                  snacks    32352      9314.50
# 15                  flight    16176      8720.00
# 16                    soda    30330      7314.00
# 17                     btg    84924      7128.25
# 18                red wine   232530      6858.50
# 19                growlers    24264      6634.00
# 20          sparkling wine   157716      6569.75
# 21               softgoods    54594      4351.00
# 22            hard seltzer    50550      3720.25
# 23              white wine   105144      3128.00
# 24                      na    72792      2632.25
# 25                double k     2022      2503.97
# 26                 seltzer    30330      2252.50
# 27          special orders    18198      2252.00
# 28          porters/stouts    56616      1684.25
# 29               rosé wine    44484      1565.50
# 30               glassware    26286      1221.00
# 31       skin contact wine    36396      1131.00
# 32  beer packages/tastings    10110      1014.50
# 33                    rosé    34374       947.50
# 34                    wild    18198       805.50
# 35                belgians    22242       758.50
# 36           hard seltzers    10110       571.50
# 37     gluten free/reduced    12132       365.00
# 38               $6 token!     2022       318.00
# 39             gluten free     4044       233.75
# 40                   misc.    14154       178.00
# 41               catering!    12132       174.00
# 42           hard kombucha     4044       171.00
# 43   hard kombucha-bottles     4044       161.00
# 44          seasonal/event     6066       129.00
# 45                big beer     2022        60.00
# 46                  zcider     2022         7.50
# 47                    zipa     2022         4.50

# %% [markdown]
# This looks pretty good. Potentially some more work to do if we wanted to collapse some of the wine categories.

# %% [markdown]
# ### Clean up beers
#
# Based on our earlier code, let's try to clean up the items that are in the beer categories. Maybe we can figure out what those are first.

# %%
all_cats = (item_info.groupby('clean_category').
    sum('gross_sales').reset_index().
    sort_values('gross_sales',ignore_index=True,ascending=False)['clean_category'].tolist())

# %%
# I used this to spot the beers and wines

start = 20
end = 50

dict(zip(range(start,end),all_cats[start:end]))
# Out:
# {20: 'sparkling wine',
#  21: 'softgoods',
#  22: 'hard seltzer',
#  23: 'white wine',
#  24: 'na',
#  25: 'double k',
#  26: 'seltzer',
#  27: 'special orders',
#  28: 'porters/stouts',
#  29: 'rosé wine',
#  30: 'glassware',
#  31: 'skin contact wine',
#  32: 'beer packages/tastings',
#  33: 'rosé',
#  34: 'wild',
#  35: 'belgians',
#  36: 'hard seltzers',
#  37: 'gluten free/reduced',
#  38: '$6 token!',
#  39: 'gluten free',
#  40: 'misc.',
#  41: 'catering!',
#  42: 'hard kombucha',
#  43: 'hard kombucha-bottles',
#  44: 'seasonal/event',
#  45: 'big beer',
#  46: 'zcider',
#  47: 'zipa'}

# %%
beer_clean_cats = []

for idx in [0,1,4,5,6,7,8,10,28,34,35,37,39] :
    beer_clean_cats.append(all_cats[idx])

# %%
# The order might change so hard-coding these in. 

beer_clean_cats = ['ipa',
 'lagers/pils/wheat',
 'sour',
 'seasonal',
 'porter/stout',
 'ambers/pales',
 'amber/pale',
 'belgian',
 'porters/stouts',
 'wild',
 'belgians',
 'gluten free/reduced',
 'gluten free']

# %%
wine_clean_cats = ['wine',
 'red wine',
 'white wine',
 'sparkling',
 'rosé wine',
 'skin contact wine',
 'rosé']

# %% [markdown]
# ### Beer Cleaning
#
# Now we're in a position to go over the items where `clean_category` is in the clean beer categories and try to
# get down to a clean item level.
#
# We'll make use of the breweries we pulled from Open Brewery DB.

# %%
breweries.to_csv("brewery_data.txt",sep="\t")

# %%
pandas_gbq.to_gbq(breweries, "umt-msba.dram_shop.brewery_data", project_id=gbq_proj_id,if_exists="replace")
# Out:
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 2557.50it/s]

# %%
brewery_data.tail()
# Out:
#                                          id                         name  \
# 8101  sufferfest-beer-company-san-francisco      Sufferfest Beer Company
# 8102            bruehol-brewing-llc-benicia          Bruehol Brewing LLC
# 8103       napa-palisades-beer-company-napa  Napa Palisades Beer Company
# 8104  headlands-brewing-company-mill-valley    Headlands Brewing Company
# 8105            high-water-brewing-stockton           High Water Brewing
#
#      brewery_type             street address_2 address_3           city  \
# 8101   proprietor  1770 UNION STREET      None      None  San Francisco
# 8102   proprietor      4828 E 2nd St      None      None        Benicia
# 8103   proprietor       1000 Main St      None      None           Napa
# 8104   proprietor               None      None      None    Mill Valley
# 8105   proprietor               None      None      None       Stockton
#
#            state county_province postal_code        country     longitude  \
# 8101  California            None  94123-3404  United States  -122.4283947
# 8102  California            None  94510-1023  United States  -122.1275637
# 8103  California            None  94559-2645  United States   -122.285449
# 8104  California            None  94941-2003  United States  -122.5449763
# 8105  California            None  95204-2943  United States  -121.2907796
#
#          latitude       phone                       website_url  \
# 8101  37.79807486  4152386431     http://www.sufferfestbeer.com
# 8102  38.08086313  7073276768            http://www.bruehol.com
# 8103    38.299359  7072961552  http://www.napapalisadesbeer.com
# 8104   37.9060368  4158604226   http://www.headlandsbrewing.com
# 8105   37.9577016  5304409098   http://www.highwaterbrewing.com
#
#                     updated_at                created_at
# 8101  2022-08-20T02:56:08.975Z  2022-08-20T02:56:08.975Z
# 8102  2022-08-20T02:56:08.975Z  2022-08-20T02:56:08.975Z
# 8103  2022-08-20T02:56:08.975Z  2022-08-20T02:56:08.975Z
# 8104  2022-08-20T02:56:08.975Z  2022-08-20T02:56:08.975Z
# 8105  2022-08-20T02:56:08.975Z  2022-08-20T02:56:08.975Z

# %%
breweries = brewery_data['name'].unique()
breweries = set(breweries)

# %%
beer_items = item_info[item_info['clean_category'].isin(beer_clean_cats)]

# %%
years = beer_items['year'].unique().tolist()

years
# Out:
# [2022]

# %%
# TODO: iterate over the years looking for new patterns.

# %%
prefix_pattern = re.compile(r"^\d\d?[a-z]? ") # going to use on lowercase
spaced_hyphen_pattern = re.compile(r" - ")

def clean_beers(item) :
    
    item = item.lower()
    
    clean_item = prefix_pattern.sub("",item)
    
    # did we have a prefix? 
    prefix = clean_item != item
        
    # A persistent misspelling
    clean_item = clean_item.replace("windmere","widmer")
    
    pieces = spaced_hyphen_pattern.split(clean_item)
    
    beer = ""
    brewery = ""
    other_info = ""

    # A few possibilities at this point. 
    # 1. item = "Roadhouse Wilson IPA": Here Roadhouse is the brewery, Wilson IPA is the beer. 
    #    I think we should look through the len(pieces) == 1 items and see if there's a brewery
    #    lurking. Similar: "Mac and Jack's African Amber 12oz can"
    # 2. item = "Fremont Brewing - Golden Pilsner 12oz can": This will successfully split, with the 
    #    brewery in spot 0 and the beer (plus form factor) in spot 1. 
    # 3. item = "05M Amber - Dos Equis": Like 2, but this one has a prefix and the beer is in spot 0.
    #    Also, "10P IPA - Big Sky Brewing"
    # 4. item = "04M Modelo Especial": Has the prefix, but won't split
    
    if not prefix and len(pieces) == 1 :
        print(item)
        print(clean_item)
        print(pieces)
        print("-"*30)

    
    return(clean_item)

# %%
items = beer_items['item'].tolist()

# %%
for idx, item in enumerate(items) : 
    
    clean_beers(item)
    
    if (idx) > 150 :
        break
# Out:
# roadhouse wilson ipa
# roadhouse wilson ipa
# ['roadhouse wilson ipa']
# ------------------------------
# mac and jack's african amber 12oz can
# mac and jack's african amber 12oz can
# ["mac and jack's african amber 12oz can"]
# ------------------------------
# blackfoot single malt ipa
# blackfoot single malt ipa
# ['blackfoot single malt ipa']
# ------------------------------
# okocim o.k lager
# okocim o.k lager
# ['okocim o.k lager']
# ------------------------------
# bitburger pilsner can
# bitburger pilsner can
# ['bitburger pilsner can']
# ------------------------------
# new hokkaido (mountains walking) yamabiko japanese lager 16oz can
# new hokkaido (mountains walking) yamabiko japanese lager 16oz can
# ['new hokkaido (mountains walking) yamabiko japanese lager 16oz can']
# ------------------------------
# new hokkaido (mountains walking) yamabiko japanese lager 16oz can
# new hokkaido (mountains walking) yamabiko japanese lager 16oz can
# ['new hokkaido (mountains walking) yamabiko japanese lager 16oz can']
# ------------------------------

# %%
item_translation = dict()
# key = original item
# value = [clean_item_name, brewery (if present), remainder (if present)]

clean_items = set()

for item in items :
    
    clean_item = prefix_pattern.sub("",item).lower()
    
    clean_item = clean_item.replace("windmere","widmer")
    
    clean_items.add(clean_item)
    pieces = spaced_hyphen_pattern.split(clean_item)
    
    beer = ""
    brewery = ""
    other_info = ""
    
    # This next section tries to get the right values in the right 
    # places for beer/brewery/other stuff
    if len(pieces) > 1 : 
        pieces = [p.strip() for p in pieces]
        
        if len(pieces) == 2 :        
            if pieces[0] in brewery_set : 
                brewery = pieces[0]
                beer = pieces[1]
            
            
            else :
                brewery = pieces[1]
                beer = pieces[0]

                
        elif len(pieces) == 3 :
            if pieces[0] in brewery_set : 
                brewery, beer, other_info = pieces
            else :
                beer, brewery, other_info = pieces
        else : 
            if pieces[0] in brewery_set : 
                brewery, beer = pieces[:2]
            else :
                beer = pieces[0]
                brewery = pieces[1]
                
            other_info = " - ".join(pieces[1:]).strip()
        
    else :
        
        clean_item_tokens = clean_item.split()
        
        
        
        for bry in brewery_set :
            if bry in clean_item : 
                brewery = bry
                beer = clean_item.replace(brewery,"")
                print(f"Brewery = {brewery}; Beer = {beer}")
            
    
#        for token in clean_item_tokens :
#            if token in brewery_set :
#                brewery = token
        
#        beer = " ".join([token for token in clean_item_tokens if token != brewery])
                
            
    item_translation[item] = [beer, brewery, other_info]

    if "Cioke" in item :
        print(item)
        print(item_translation[item])

# %%
for b in breweries : 
    if 'roadhouse' in b.lower() :
        print(b)
# Out:
# Roadhouse Pub and Eatery
# Roadhouse Brewing Company
# McMenamins Cornelius Pass Roadhouse

# %%
breweries
# Out:
# {'Forward Operating Base Brewing Company / FOB Brewing',
#  'Point Labaddie Brewery',
#  'Old Market Pub and Brewery',
#  'Farmington Underground Canning and Kegging',
#  'Dragon Hops Brewing',
#  'Bandwagon Brewery',
#  'Banded Brewing Company',
#  'Park City Brewery',
#  'Four Quarters Brewing Co',
#  'Backswing Brewing Co.',
#  'Steele and Hops Public House',
#  'All Saints Brewing Co',
#  'Orange County Brewers',
#  'From The Earth Brewing Company',
#  'Two Goats Brewing',
#  'Durango Brewing Co',
#  'Fyne Ales',
#  'Chimera Brewing Company',
#  'Right Around The Corner',
#  'Sugarfoot Saloon',
#  'In the Shadow Brewing',
#  'At Large Brewing',
#  'Diamond Mountain Brewery',
#  'Here and Now Brewing Co',
#  'Spangalang Brewery',
#  'Crue Brew Brewery',
#  'Farnam House Brewing Company',
#  'Brew 32',
#  'SanTan Brewing Co - Uptown Chandler',
#  'Ludlam Island Brewery',
#  'Belle Isle Restaurant and Brewing Co',
#  'Dimensional Brewing Co.',
#  'Black Sky Brewery',
#  'Rockslide Brewing Co',
#  'Gordon Biersch Brewery Restaurant - Annapolis',
#  'Paonia United Brewing Company',
#  'Alchemist Cannery',
#  'Modern Times Beer',
#  'Lengthwise Brewing Co',
#  'Cheluna Brewing Company',
#  'Mechanistic Brewing',
#  'Highmark Brewery',
#  "Gonzo's BigDogg Brewery",
#  'The Barley House Brewing Company LLC',
#  'Foothills Brewing and Beverage Co',
#  'New Terrain Brewing Company',
#  'Commonwealth Brewing Co.',
#  'Barrel Mountain Brewing',
#  'Liars Bench Beer Company',
#  'Lunar Brewing Co',
#  'Cold Fusion Brewing LLC',
#  'Burke-Gilman Brewing',
#  'Foreign Objects Beer Company',
#  'Calapooia Brewing Co / Siletz Ales',
#  'Pinthouse Pizza North',
#  'Muskellunge Brewing Company',
#  'Kettle and Spoke Brewery, LLC',
#  'The Village Corner',
#  'Able Seedhouse and Brewery',
#  'Karl Strauss Brewing Co - Sorrento Mesa',
#  'Minglewood Brewery',
#  'Far Gohn Brewing Company',
#  'Tannery Bend Beerworks',
#  'Cerebral Brewing',
#  'The Humble Pint',
#  'Cape Ann Brewing Co',
#  'Brick & Mortar Brewing Company',
#  'Dubious Claims Brewing',
#  'Colorado Mountain Brewery At the Roundhouse',
#  'North Park Beer Co.',
#  'The Harmony Inn',
#  'Ookapow Brewing Company',
#  '1188 Brewing Co',
#  'Maplewood Brewing Company',
#  "Devil's Trumpet Brewing Co",
#  'Pigeon Hill Brewing Co',
#  'Virginia City Brewery & Taphouse',
#  'Three Stacks and A Rock Brewing Co',
#  'Copper City Brewing Company',
#  'High Alpine Brewing Company',
#  'Cloudburst Brewing on Shilshole',
#  'Bloom Brew',
#  'Boulevard Brewing Co',
#  'Arundel Cellars & Brewing Co',
#  "Beale's",
#  'Bull and Goat Brewery',
#  'Dead Bird Brewing Company',
#  'Links Brewing Company',
#  'Lake Time Brewery',
#  'Wild Barrel Brewing Company',
#  'Lake Austin Ales',
#  'Skull Camp Brewing',
#  'St Arnulf Alery',
#  "Topsy's",
#  'Three Creeks Brewing Co',
#  'Great Flood Brewing- Production Facility',
#  'Saint Somewhere Brewing Co',
#  'Powerhouse Restaurant and Brewery',
#  'Preyer Brewing Company',
#  'Hayesville Brewing Co',
#  'Anthem Brewing Co',
#  'Riverside Brewing Ltd',
#  'NoCoast Beer Co',
#  'Backyard Brewery',
#  'Taylor House Brewing Co',
#  'Outlaw Brewing Co',
#  'Campbell Brewing Co',
#  'Matties',
#  'Stone Brewing World Bistro & Gardens- Liberty Station',
#  'Neon Groundhog Brewery - Majestic Oak Winery',
#  'Mountain Lakes Brewing Company',
#  'Laughing Sun Brewing',
#  'Industrial Arts Brewing Co.',
#  "Witch's Hat Brewing",
#  'Racine Brewing Co',
#  'Mraz Brewing Company',
#  'U4ic Brewing, Inc.',
#  'Sidellis Lake Tahoe',
#  'Bayou Teche Brewing',
#  'Jagged Mountain Brewery',
#  'Hana Koa Brewing Company',
#  'John Harvards Brew House - Framingham',
#  'Ghost Train Brewing Co',
#  'Kissingate Brewery',
#  'Old Colorado Brewing Co',
#  "Bennidito's Brewpub",
#  'Galveston Bay Beer Company, Inc.',
#  'Wynwood Brewing Company',
#  'Pointless Brewery',
#  'Bonaventure Brewing Co',
#  'Boondocks Brewing',
#  'Gladiator Brewing Co.',
#  'Texas Beer Company',
#  'Rhythm River Brewing Company',
#  'The Berghoff Brewery Inc.',
#  'Mankato Brewery',
#  'Tin Dog Brewing',
#  'Four Sons Brewing',
#  'Granite City Food & Brewery (#8)',
#  'Roobrew',
#  'ChuckAlek Independent Brewers',
#  'Clayton Brewing Co',
#  'Great Basin Brewing Co - Production Facility',
#  'Iron Fist Brewing Co',
#  'Black Beak Brewing',
#  'Olde Hickory Brewery - Production',
#  'The Livery',
#  'Nowhere In Particular Brewing Company',
#  'Halyard Brewing Company',
#  'Moustache Brewing Co',
#  'Bond Brothers Beer Company',
#  'Faultline Brewing Co',
#  'Crystal Springs Brewing Co',
#  'Erie Brewing Co',
#  'Salt Point Brewing Co, LLC',
#  '5x5 Brewing Co.',
#  'Battery Steele Brewing',
#  'Stache Rabbit Brewing Company',
#  'Liberty Street Brewing Production Facility',
#  'Ferrari Beer Company',
#  'Main Street Brewery',
#  'Hatchet Brewing Company',
#  'Vanport Brewing Company',
#  'Bawden Street Brewing Company',
#  'Piece Brewery',
#  'Wages Brewing Company',
#  'Rahr and Sons Brewing Co',
#  'Palmetto Brewing Co',
#  'High Point Brewing Co, Inc.',
#  'On Tour Brewing Co.',
#  'Baffin Brewing Co',
#  'Watts Brewing Company',
#  'Maple Lawn Brewery',
#  'Great South Bay Brewery',
#  'Brew Republic Bierwerks',
#  'Canyon Club Brewery',
#  'Align Brewing Co',
#  "Friars' Brewhouse",
#  'Friends and Allies Brewing Company',
#  'Ottos Pub & Brewery',
#  'Oasis Brewery',
#  'Alta Brewing Company',
#  'Optimism Brewing Company',
#  'Crooked Crab Brewing Company',
#  'Holler Brewing Company',
#  'Starr Hill Pilot Brewery & Side Stage',
#  'Sigma Brewing Company',
#  'The Tank Brewing Company',
#  'Hardywood Park Craft Brewery-Charlottesville',
#  'Raw Deal',
#  'Old Dog Alehouse & Brewery',
#  'Claimstake Brewing Company',
#  'Sherpa Brewery Pvt. Ltd.',
#  'Cannon Brewpub',
#  'Smoky Mountain Brewery (#1)',
#  'LauderAle',
#  'Ellison Brewery & Spirits',
#  'Maui Brewing Co - Lahaina',
#  'Râ\x80\x99Noggin Brewing',
#  'Twenty Below Brewing @ Twenty Tap',
#  'Elmhurst Brewing Company',
#  'Lager Heads Brewing Co.',
#  'Revolution Brewing - Brewpub',
#  '동두천브루어리(Dongducheon Brewery)',
#  'Animas Brewing Co',
#  'Tuppers Hop Pocket Ale',
#  'Sun King Brewing Co',
#  'Orlando Brewing Partners, Inc.',
#  'Fredonia Brewery, LLC',
#  'Wissahickon Brewing Company',
#  'Brew Hub, LLC',
#  'Helicon Brewing',
#  'Holy Mountain Brewing Co',
#  'Free Will Brewing Company',
#  'Out of Bounds Brewing Company',
#  'Separatist Beer Project',
#  'K-Oz Restaurant Brewery',
#  'Ventura Coast Brewing Company',
#  'Legends Brewhouse and Eatery (#1)',
#  'Saint Hazards Brewery',
#  'Aurora Ale & Lager',
#  'The Star Spangled Brewing Co.',
#  'Hop Haus Brewing Co',
#  'Abridged Beer Company',
#  'Tin Lizard Brewing Co',
#  'Les Cheneaux Distillers',
#  'Concord Craft Brewery',
#  'Buffalo Brewing Company',
#  'Oak Park Brewing Co',
#  'John Scott Brewing Co.',
#  'Black Label Brewing Company',
#  'Sound Brewery',
#  'The Portsmouth Brewery',
#  'South Cypress Brewing',
#  'High Gravity Brewing Company',
#  'Rising Sons Brewery',
#  'Phantom Horse Brewing',
#  'Midtown Brewing Co',
#  'Threefoot Brewing Company, LLC',
#  'Stumptown Ales',
#  'Insurrection Aleworks',
#  'Beehive Basin Brewery',
#  'Pigeon River Brewing',
#  'Fountainhead Brewing Co',
#  'Ascension Brewing Company',
#  'Secatogue Brewing Co.',
#  '14 Cannons Brewing Company',
#  'Maxline Brewing',
#  'Parish Brewing Company',
#  'The Red Yeti',
#  'McMenamins Mill Creek Brewery',
#  'Stoneman Brewery',
#  'White Gypsy Brewery',
#  'Lake Bluff Brewing Company',
#  'Laines Brew Hub',
#  'Granite City Food & Brewery (#10)',
#  'Boscos Squared',
#  'Big Cat Brewing Company',
#  'Sea Dog Brewing Co',
#  'Moon River Brewing Co',
#  'Clouds Brewing',
#  "Big Dog's Brewing Co",
#  'The Dancing Fox',
#  'Savannah Beer Company',
#  'Radius Brewing Company',
#  'River Time Brewing',
#  '1912 Brewing',
#  'Out World Brewing',
#  'SanTan Brewing Co',
#  'Brown Truck Brewery',
#  'Pizza Port Ocean Beach',
#  "Buster's Brew Pub",
#  'Ruba Brewing',
#  'Odd Side Ales',
#  'Kobold Brewing',
#  'Archetype Brewing',
#  'Old Bust Head Brewing Co.',
#  'Flytrap Brewing',
#  'Johanssons Dining House',
#  'Reno Brewery',
#  'Old House Vineyards',
#  'Third Street Brewhouse',
#  'Sunset Reservoir Brewing Company',
#  'Old Spruce Brewing',
#  'Rippon Brewing Company',
#  'Ironbark Brewery',
#  'WhichCraft Brews',
#  'Dead Bear Brewing Co',
#  'Pumphouse Brewery and Restaurant',
#  'Ruse Brewing, LLC.',
#  'Levi Garrison & Sons Brewing Company',
#  'Funguys Brewery',
#  'Smiling Toad Brewery',
#  'Lone Peak Brewery',
#  'Copper Turret Restaurant and Brewhouse',
#  'Little House Brewing Company',
#  'Grist Iron Brewing Co.',
#  'Sly Fox Brewhouse and Eatery',
#  'SKA Brewing',
#  'Charlie and Jakes Brewery and Grille',
#  '인천맥주(incheon_brewery)',
#  'Arcana Brewing Company',
#  'Great Lakes Brewing Co',
#  'Southbound Brewing Co',
#  '라미브루잉(Rami Brewing)',
#  'Hop Hill Brewing Company',
#  'Stones Throw Brewery',
#  'OK3 Brewing Company',
#  'Pocono Brewery Company',
#  'Dead Lizard Brewing Company',
#  'Fat Toad Brewing Company',
#  'Mecan River Brewing Company',
#  'Chilly Water Brewing Company',
#  'Long Table Brewing',
#  'Verde Brewing Company',
#  'Prairie Artisan Ales',
#  'Bog Turtle Brewery, LLC',
#  'Broken Arrow Brewing Co.',
#  'Townies Brewery',
#  'Granite City Food & Brewery (#3)',
#  'Sconnie Beverage',
#  'Nocterra Brewing Co',
#  'Boots Brewing Company, Inc.',
#  'Cape Ann Lanes',
#  'Relentless Brewing Co',
#  'Cold Spring Brewery',
#  'Surly Brewing Company',
#  'Northwoods Brewing Co',
#  'RAM Restaurant and Brewery - Lakewood',
#  'Anvil Brewing',
#  'Shrub Steppe Smokehouse Brewery',
#  'Mountain Town Brewing Co',
#  'New Mexico State University Department Of Chemical',
#  'Blue Island Beer Co',
#  'Bigelow Brewing Company',
#  'Abbey Brewing Co',
#  'Broken Bow Brewery',
#  'Coelacanth Brewing',
#  'Brewing Savage Co.',
#  'Outer Banks Brewing Station',
#  'Under the Rose Brewing Company MidTown Location',
#  "Mason's Brewing Company",
#  'Fleur De Lis Brew Works',
#  'Kretschmann Brewing Company',
#  'Pennyweight Craft Brewing',
#  'Werk Force Brewing Co',
#  'Arrowood Farms',
#  'Pacific Brew Lab',
#  'Bhramari Brewhouse',
#  'Long Ireland Brewing Co',
#  'The Collective Brewing Project',
#  'Lake Gaston Brewing Company',
#  'Franklin Street Brewing Company',
#  'KelSo Beer Company',
#  'Iron Flamingo Brewery',
#  'Stateline Brewery',
#  'Throwback Brewery',
#  'Bull Creek Brewing Company',
#  'Open Door Brewing Company',
#  'Paradox Beer Co',
#  'Uptown Market Brewing',
#  'Peabody Heights Brewery',
#  'InnerSpace Brewing Company',
#  'Counterweight Brewing Company',
#  "Parker's Steakhouse and Brewery",
#  'Peaks and Creeks Brewing Company',
#  "Emmett's Brewing Co - Wheaton",
#  'River North Brewery',
#  'Ghost Monkey Brewery',
#  'Bar Hygge / Brewery Techne',
#  'Pawleys Island Brewing Company',
#  'Birreria @ Eataly',
#  'Common Space Brewery',
#  'J.J. Bitting Brewing Co.',
#  'Chelsea Alehouse Brewery',
#  'Scottsdale Beer Company',
#  'Oggis Pizza & Brewing Co - Carmel Mountain Ranch',
#  'Shiny Top Brewing',
#  'Victory Brewing Co',
#  'Eleventh Hour Brewing Co',
#  'Black Creek Brewery',
#  'Jaw Brew',
#  'Ghost Isle Brewing Company',
#  'Soo Brewing Company',
#  'Postdoc Brewing Company',
#  'Fulton Chain Craft Brewery',
#  "McFleshman's Public House",
#  'East End Brewing Co',
#  'Corcoran Brewing',
#  'Arbor Brewing Co',
#  'Armistice Brewing Company',
#  'Turtle Anarchy Brewing Co',
#  'Omega Brewing Experience',
#  'Four String Brewing Company',
#  "Fiddlin' Fish Brewing Company",
#  'Lovelady Brewing Company',
#  'Neuse River Brewing Company',
#  'Pigeon Head Brewery',
#  'Beer By Design Brewery',
#  'HopFly Brewing Company',
#  'Brewery 26',
#  'Brew Works of Fremont',
#  "Dudes' Brewing Co",
#  'Twin Lakes Brewing Co',
#  'Rother Valley Brewing Company',
#  'Bookhouse Brewing, LLC.',
#  'Pelican Brewing Company',
#  'Motor City Brewing Works Warehouse',
#  'Odd Alewives Farm Brewery',
#  'Zaftig Brewing Co.',
#  'Klaus Brewing Company',
#  'Intergalactic Brewing Co',
#  'Duvig Brewing Co',
#  'River Bluff Brewing',
#  'Topa Topa Brewing Co',
#  'Bluewood Brewing',
#  'Green Oak Brewing',
#  'Harlem Blue Beer',
#  'Solace Brewing Company',
#  'Lakes & Legends Brewing Company',
#  'Reed City Brewing Company',
#  'Flying Belgian Brewery',
#  'Portland Brewing/North American Breweries',
#  'Paper Street Brewing Company',
#  'Wagner Valley Brewing Co',
#  "Angry Hank's Microbrewery",
#  'Beaver Street Brewery',
#  'Sanctum Brewing Co',
#  'Back Bay Brewing Company',
#  'South Street Brewery',
#  'Lucky Star Brewery',
#  'Acopon Brewing Co',
#  'Tomoka Brewing Company',
#  'Wildrose Brewing Company',
#  'Hoops Brewing',
#  'Hix Farm Brewery',
#  'St. Pete Brewing Company',
#  'Doylestown Brewing Co',
#  'Norris English Pub',
#  'Salem Beer Works',
#  "Burke's Alewerks",
#  '크래머리 브루어리(Kraemerlee Brewery)',
#  'Gilded Otter Brewing Co',
#  'Stable 12 Brewing Company',
#  'Breakwater Brewing Co',
#  'Platform Beer Co Taproom',
#  'Old Detroit Brewing Co',
#  'Depot Street Brewing Co',
#  "Brew D'Etat",
#  'Coastal Bend Brewing',
#  'Draper Brewing',
#  'Rock God Brewing Company',
#  'Green Wolf Brewing Co',
#  'Porchlight Brewing Company',
#  'Hoparazzi Brewing Co',
#  'Stone Cellar Brewpub / Stone Arch Brew House',
#  'Owls Roost Brewing',
#  "Brighter Day's Brewing Company",
#  'Deft Brewing',
#  'Lucky Pigeon Brewing',
#  'Upside Brewing',
#  'Fretboard Brewing Company',
#  'King Canary Brewing Company',
#  'Marble Brewery - Mav Lab',
#  'Braxton Labs',
#  'Nale House Brewing Co',
#  'Castleburg Brewery',
#  'Strum Brewing Company',
#  'Dublin City Brewing Co.',
#  'Calfkiller Brewing Co',
#  'Gordon Biersch Brewery Restaurant - Tempe',
#  'Mohegan Cafe and Brewery',
#  'Hightower Brewing Co',
#  'RiverBend Brewing Pub',
#  'Cedar Creek Brewing Co.',
#  'D. G. Yuengling and Son Inc',
#  'Asheville Brewing Co',
#  '9th Hour Brewing Company LLC',
#  'No Label Brewing Co',
#  'Brugge Brasserie',
#  'Small Brewpub',
#  'Cascadia Brewing Co.',
#  'Baltimore Washington Beer Works',
#  'Structures Brewing',
#  'Modern Times Barrel House',
#  'Chafunkta Brewing Co',
#  'Corsair Artisan LLC',
#  'Rickety Cricket Brewing',
#  'Tin Cannon Brewing Company',
#  'Dented Face Brewing Company',
#  'Old Coast Ales',
#  '4th Tap Brewing Cooperative',
#  '350 Brewing Co',
#  'Westlake Brewing & Libation',
#  'Bang Brewing',
#  'Sauced BBQ & Spirits',
#  'Paw Paw Brewing Company LLC',
#  '16 Mile Brewing Co',
#  'Wandering Star Brewing Co',
#  'Right Mind Brewing',
#  'Cerveza Guajira',
#  '8th Ward Brewing Company',
#  'ZeLUS Beer Company',
#  'Aztec Brewing Company',
#  'Auburn Brewing Company',
#  'Tie and Timber Beer Company',
#  'Midwest Hop Producers LLC',
#  'Elysian Brewing Co',
#  'Claim 52 Brewing',
#  'Lost Highway Brewing',
#  'Melvin Brewing Co',
#  'Upland Brewing Co - Bloomington Brewpub',
#  'Paystreak Brewing',
#  'Two Kilts Brewing',
#  'New York Beer Project',
#  'Enumclaw Brewing Company @ Rockridge Orchards & Cidery',
#  'Burghâ\x80\x99ers Brewing',
#  'Kennedy Vineyard',
#  'Naughty Monk Brewery L.L.C.',
#  'Steady Habit Brewing Company',
#  '2Kids Brewing Company',
#  'Key City Brewing Co.',
#  'Black Forest Brewery',
#  'New Sarum Brewing',
#  'Balter Beerworks',
#  'Relic Brewing',
#  'Cottrell Brewing Co',
#  'Bridewell Brewery',
#  'Craft Brewing Company',
#  'Good Things Brewing Co Ltd',
#  'Tumbledown Brewing LLC',
#  'Metazoa Brewing Co.',
#  'Dog Tag Brewing',
#  'Toy Soldier',
#  'Frisco Tap House & Push Brewery',
#  'Sonoma Springs Brewing Co',
#  '5 Alarm Brewing Co',
#  "Bell's Brewery, Inc",
#  'Lakewood Brewing Co',
#  'Jughandle Brewing Co LLC',
#  'Lucky Monk Burger, Pizza & Beer Co',
#  'Aleman Brewing',
#  'Rusty Nickel Brewing Co.',
#  'Johnson City Brewing Co',
#  'Brewdog Short North & Kennels',
#  'Breakside Brewery & Taproom',
#  'Salt Flats Brewery',
#  'Culver Beer Company',
#  'Smoky Mountain Brewery (#3) - Pigeon Forge',
#  'Albia Brewing Co',
#  'Cage Brewing',
#  'Hops Brewery',
#  'Kings County Brewers Collective',
#  'CRAFT 64',
#  'Jacob Leinenkugel Brewing Co',
#  'Red Lodge Ales Brewing Co',
#  'Belding Brewing Company',
#  'John S. Rhodell Brewery',
#  'Egan & Sons',
#  'Kenai River Brewing Co',
#  'Will County Brewing Company',
#  'River City Brewing',
#  'Vanish Farmwoods Brewery',
#  'Black Gold Brewing Co',
#  'Munkle Brewing Company',
#  'Athens Brewing Co',
#  'Jailbreak Brewing Company',
#  'Gilgamesh Brewing Co',
#  'Broken Tooth Brewing Co',
#  'HenHouse Brewing',
#  'Stellwagen Beer Company',
#  'Flatland Brewery',
#  'Twisted Pine Brewing Co',
#  'Side Door Brewing Company',
#  'Uberbrew',
#  'Sing Sing Kill Brewery',
#  'Laht Neppur Brewing',
#  'Lazarus Brewing Company',
#  'Endless Brewing',
#  'Brass Ring Brewery',
#  'Suncreek Brewery',
#  'Lunkenheimer Craft Brewing Co. LLC',
#  'Stargazer Brewing Company',
#  'Palmer Brewery & Cider House',
#  'Mill City Brew Werks',
#  'Lumber House Brewing Company',
#  'Main Channel Brewing Company',
#  'Hoster Brewing Co',
#  'New Axiom Brewing Company',
#  'Matanuska Brewing Company - Midtown Brewpub',
#  'Start Line Brewing Company',
#  'Timber Creek Tap & Table',
#  'Stadium Pizza - Murrieta',
#  'IMBIB Custom Brews',
#  'Soggy Bottom Brewing Co.',
#  'Transient Artisan Ales',
#  'BeachFly Brewing Company',
#  'Earthen Ales',
#  'Lil Paws Winery',
#  'Highland Park Brewery',
#  'Funk Brewing Company',
#  "Taft's Brewing Co",
#  'Plan Bee Farm Brewery',
#  'Creatures Of Habit Brewing Co',
#  'Mother Earth Brew Co LLC',
#  'Salud Cerveceria',
#  'Pulpit Rock Brewing Co.',
#  'The Beer Diviner',
#  'Alter Brewing Company',
#  'Burial Beer Co Forestry Camp',
#  'Bismarck Brewing',
#  'Still HIll Brewery LLC',
#  'Covington Brewhouse',
#  'Batch Brewing Co',
#  "Emmett's Brewing Co - Palatine",
#  'Band of Brothers Brewing Company',
#  'Sand Creek Brewing Co',
#  'Dublin Corners Farm Brewery',
#  'Hepworth & Company Brewing Ltd',
#  'Carolina Bauernhaus Ales',
#  'Proof Brewing Co',
#  'Half Day Brewing Company',
#  'Moonraker Brewing Company (Production Facility)',
#  'Orange Cat Brewery',
#  'Crooked Can Brewing Co',
#  'Blues City Brewing Co',
#  'Thirsty Planet Brewing Co',
#  'Triceratops Brewing',
#  'Port Huron Brewing Co',
#  'Sequoia Brewing Co - Tower District',
#  'Icebox Brewing LLC',
#  'Varietal Beer Company',
#  "Granary 'Cue and Brew",
#  'Granite City Food & Brewery (#28)',
#  'Farm Road Brewery',
#  'Southern Appalachian Brewery',
#  'Zillicoah Beer Company',
#  'Fire Maker Brewing Company',
#  'Carver Brewing Co',
#  'Westtown Brew Works',
#  'Apocalypse Ale Works',
#  'The Long Man Brewery',
#  'Midnight Jack Brewing Company',
#  'Martin City Brewing Company',
#  'Inc 82 Brewing',
#  'Altmeyer and Lewis Brewing Company',
#  'Creek Bottom Brew LLC',
#  'Whistle Hop Brewing Company',
#  'On Rotation Brewery',
#  'Verboten Brewing',
#  'Drew Fox Brewing Company',
#  'Tequesta Brewing Co',
#  'Ola Brew Co.',
#  'Crystal Ball Brewing',
#  'Santa Cruz Aleworks',
#  'In-Law Brewing Co',
#  'Quarter Barrel Brewery and Pub',
#  'Lake Monster Brewing',
#  'Invictus Brewing Co',
#  'Anheuser-Busch Inc - Los Angeles',
#  'East Troy Brewery',
#  "Short's Brewing Co",
#  'Glover Park Brewery',
#  'Kalona Brewing Company',
#  'Pennsylvania Brewing Co',
#  'Tanzenwald Brewing Company',
#  'James River Brewery',
#  'Vierling Restaurant & Marquette Harbor Brewery',
#  'Genus Brewing and Supply',
#  'Dillon Dam Brewery',
#  "Nun Chuck's Brewing Co",
#  'Meadowlark Brewing',
#  'Taproot Brewing Co / Newport Vineyards',
#  'Brothers Cascadia Brewing',
#  'BarmHaus Brewing Co',
#  'Pacific Brew Haus',
#  'Twisted Barley Brewing Company',
#  'Scriptown Brewing Company',
#  'Half Barrel Beer Project',
#  'Jekyll Brewing',
#  'Third Nature Brewing Co.',
#  'West O Beer',
#  'Beachwood BBQ & Brewing',
#  'Big Bear Lake Brewing Co',
#  'BS Brewing',
#  'Fetch Brewing Co',
#  'Bainbridge Brewing',
#  'Thunder Canyon Brewery',
#  'Bute Brew Co',
#  'Stickman Brews',
#  'Rotunda Brewing',
#  'The Mitten Brewing Co',
#  'Left Coast Brewing Co.',
#  'Whistle Pig Brewing Company',
#  'Lady Justice Brewing Company',
#  'Kern River Brewing Co',
#  'Mash Cult Brewing',
#  'Turtle Swamp Brewing',
#  'Oak Grove Brewing Company',
#  'Tallgrass Taphouse Co',
#  '5 Lamps Brewery',
#  'Pro Re Nata Brewery',
#  'Packinghouse Brewing Co, The',
#  'Double Bluff Brewing',
#  'Willow Rock Brewing Company',
#  'Waikiki Brewing Company',
#  "Grandma's House",
#  'Fort Rock Brewing',
#  'Wiley Roots Brewing Co',
#  'Snowbank Brewing',
#  'Stoic Brewing',
#  'White Lion Brewing Company',
#  'Bugnutty Brewing Company',
#  'Local Option',
#  'Perfect Plain Brewing Co.',
#  'Dwinell Country Ales',
#  'Redemption Alewerks',
#  'Sibling Revelry Brewing',
#  'Free State Brewing Co',
#  "Foster's Pint & Plate",
#  'Thirsty Bro Brewing',
#  'De Garde Brewing',
#  'Pure Order Brewing Co',
#  'Whole Foods Market Brewing Company- Floodcraft Brewing',
#  'Paramount Brewing Company',
#  'Ursa Minor Brewing',
#  'Wingman Brewers',
#  'Rinn Duin Brewing',
#  'Granite City Food & Brewery (#2)',
#  'Apex Aleworks Brew And BBQ Supplies',
#  'Benchtop Brewing Company',
#  'Brewhouse & Kitchen',
#  'Edge Of The World Brewery',
#  'Blind Tiger Brewery & Restaurant',
#  'Urban Renewal Brewery',
#  'Colludium Brewery',
#  'Wheatland Spring Brewery',
#  'Paddle Hard Brewing',
#  'Roots Brewing Company',
#  'Belching Beaver Brewery Tavern & Grill',
#  'MT Head Brewing Co',
#  '2C Family Brewing Co.',
#  'Omaha Brewing Company',
#  'Olde Main Brewing Co & Restaurant',
#  'North Country Canning Co',
#  'Blue Star Brewing Co',
#  '412 Brews',
#  'Bluestone Brewing Company',
#  'Empire City Beer Company',
#  'Vicious Fishes Brewery',
#  'Alma Mader Brewing',
#  'Logboat Brewing Co',
#  'Boulder Dam Brewing Company',
#  'Poor House Brewing',
#  'Platte Creek Brewing Company',
#  'Ruby Mountain Brewing Co',
#  'Smylie Brothers Brewing Co',
#  "Hapa's Brewing Company",
#  'Center Square Brewing / Altland House',
#  'Highway 79 Brewery',
#  'Rock Bottom Brewery - Denver',
#  'Big Muddy Brewing Co',
#  'Monkey Wrench Brewing Company LLC',
#  'Ulele Spring Brewery',
#  "Martha's Exchange Restaurant and Brewery",
#  'Inoculum Ale Works',
#  'Cavendish Brewing Company',
#  'Dakota Point Brewing LLC',
#  'Basement Brewers of Texas',
#  'One Brewing / Harmony Meadows Center',
#  'Burgundian Brewing Co.',
#  'Mitten Brewing Co - Northport',
#  'American Brewing Company',
#  'Deep Space Brewing / Out of This World Pizza',
#  'Lazy Tree Ranch Brewing',
#  'Berthoud Brewing Company',
#  "Zed's Beer/Bado Brewing",
#  'Abnormal Beer Company',
#  '10 Barrel Brewing Co - Boise',
#  'Seminar Brewing',
#  'Salty Turtle Beer Company',
#  'Old Bisbee Brewing',
#  'Sacred Waters Brewing Company',
#  'Berkley Beer Company',
#  'Two Rows Restaurant and Brewery - Allen',
#  'SlickFin Brewing Company LLC',
#  'Ozarks Brewing Company',
#  'Outland Brewing Company',
#  'Phase 2 Brewing',
#  'Blue Frog Brewing Company',
#  'Building 8 Brewing',
#  'Storybook Brewing',
#  'Griesedieck Brothers Brewery',
#  'Ratchet Brewery Silverton',
#  'Three Bull Brewing Co',
#  'Fury Brewing Company',
#  "1940's Brewing Company",
#  '감자아일랜드(Gamja Island)',
#  'Little Apple Brewing Co',
#  'Revelation Craft Brewing Co',
#  'JP DasBrew',
#  'Dirt Farm Brewing',
#  'Trail Point Brewing Co.',
#  'Idle Hands Craft Ales',
#  'River Rouge Brewing Company',
#  'Foolproof Brewing Company',
#  'Last Days of Autumn Brewing',
#  'Abjuration Brewing',
#  'Seneca Street Brew Pub',
#  'Black Frog Brewing Co',
#  'Antiques on High',
#  'Triple Voodoo Brewing Co',
#  'Forbidden Root Restaurant & Brewery',
#  'Underground Brewing',
#  'Redbeard Brewing Co',
#  'Jessup Farm Barrel House',
#  'Water Street Brewing Co',
#  'McMenamins Kalama Harbor Lodge',
#  'Barrel and Beam',
#  'Box Office Brewery',
#  'Hanging Hills Brewing Company',
#  'Terrapin Beer Co',
#  'Blank Canvas Brewery',
#  'Commonhouse Ales',
#  'No Clue Craft Brewery',
#  'Turgua Brewing Co',
#  'Public House Brewing Company',
#  'McMenamins Concordia Brewery at Kennedy School',
#  'The Split Batch Brewery',
#  'Dialectic Brewing Company',
#  'Billsburg Brewery',
#  'Cash Brewing Company',
#  "World's End Brewpub",
#  'Four Eyed Guys Brewing',
#  'Dog Money Restaurant',
#  'Last Name Brewing',
#  'Legacy Ale Works',
#  'Torg Brewery',
#  'Harpers Restaurant and Brewpub',
#  'Greenstar Brewing At Uncommon Ground',
#  'Mountain Layers Brewing Company',
#  'Flyover Brewing Co',
#  'Liberty Street Brewing Co',
#  'Spice Trade Brewing',
#  'Old Town Abbey Ales',
#  'Hillsdale Brewing Company',
#  'Savannah River Brewing Company',
#  'Bonsai Brewing Project',
#  'Brewery At Simmzys Burbank',
#  'IDK Beer Co',
#  'Central Standard Brewing',
#  'Byway Brewing Company',
#  'Redhook - Cataqua Public House',
#  'Lock City Brewing',
#  'Two Bald Guys Beverage Co',
#  'Foxtown Brewing',
#  'Outer Planet Craft Brewing',
#  'H.A. Brewing Co',
#  'Boulder Beer Co',
#  'Ruby Valley Brew',
#  'O.H.S.O. Brewery - Gilbert',
#  'The Franciscan Well Brewery',
#  'Daredevil Brewing Company',
#  'Union Station Brewery',
#  'Four Peaks Brewery & Taproom',
#  'Uranus Brewery',
#  'Sub Noir Brewing Company',
#  'Flat Earth Brewing Co',
#  'Pantomime Mixtures',
#  'THAT Brewery - Cottonwood',
#  'Deep Brewing Company',
#  'Monolitch Brewing Company',
#  'Gakona Brewing Company',
#  'Garland Brew Werks',
#  'Hop Farm Brewing Co',
#  'Ellersick Brewing / Big E Ales',
#  'Cigar City Airport Location',
#  'Snowy Mountain Brewery',
#  'Jack Russell Farm Ales',
#  'Solarc Brewing',
#  'Pretentious Beer Co',
#  'Dirigo Brewing Co.',
#  'Mother Bunch Brewing, Inc.',
#  'Rock Bottom Brewery - Minneapolis',
#  "Duncan's Abbey",
#  'Bath Brewing Company',
#  'Redlight Redlight Beer Parlour and Brewery',
#  'Trek Brewing',
#  'Old Klaverack Brewery',
#  'Ex Novo Brewing Co',
#  'The Public Option',
#  'Iowa River Brewing Company',
#  'Latitude 33 Brewing Co',
#  'Broken Clock Brewing Cooperative',
#  'Elevator Brewery and Draught Haus',
#  'Highlands Hollow Brewhouse',
#  'Saddle Rock Pub & Brewery',
#  'Pitchers Sports Restaurant and Brewery',
#  'Big Island Brewhaus',
#  "B and J's Handcrafted Texas Ales",
#  'South Austin Brewery',
#  'Over Yonder Brewing Company',
#  'Iowa Brewing',
#  "St. Benedict's Brew Works",
#  'Montavilla Brew Works',
#  'Ogopogo Brewing',
#  'Broken Bat Brewing Company, LLC',
#  'Depot Deli and Lounge',
#  'Rock County Brewing Company',
#  "Waddell's Brewing Co.",
#  'No Worries Brewing Company',
#  'Bridal Veil Brewing',
#  'Nostrum Brewing',
#  'Peckish Pig',
#  'Ill Mannered Brewing Company',
#  'Ironwood Creek',
#  'Shy Bear Brewing',
#  'Odd Breed Wild Ales',
#  'Magnify Brewing Company',
#  'Stormcloud Brewing Company',
#  'Gun Brewery Ltd',
#  'RAM Restaurant and Brewery - Clackamas',
#  'Eagle Creek Brewing Company',
#  'Red Hawk Brewing',
#  "Oggi's Sports Brewhouse Pizza - Upland",
#  'Titanic Brewing Co',
#  'Fountain Square Brewing Co',
#  'Imminent Brewing',
#  'Steamworks Brewing Co',
#  'Union Pizza & Brewing Co',
#  'Uniontown Brewing Co.',
#  'BJs Restaurant & Brewery - Brea',
#  'Ale Republic',
#  "McClellan's Brewing Company",
#  'Eagle Park Brewing Company',
#  'Great Barn Brewery',
#  '56 Brewing',
#  'Greyhound Brewery ltd',
#  'Brioux City Brewery',
#  'River Bend Hop Farm And Brewery',
#  'Industry Brewery',
#  'Kaktus Brewing Co.',
#  'LazyG Brewhouse',
#  'TRVE Brewing Co',
#  'Cycle Brewing Production and Warehouse',
#  'Bosque Brewing Co - Bosque North',
#  "Pair O' Dice Brewing Company",
#  'Rural Brewing Company',
#  'Noble Rey Brewing Company',
#  'Crew Brewing Company',
#  'Morgan Territory Brewing',
#  '12 West Brewing Company - Production Facility',
#  'StillWest Brewery & Grill',
#  'YellowBelly Beer',
#  'Galena Brewing Co',
#  'Crafty Ales and Lagers',
#  'Mackinaw Trail Brewing Company / Mackinaw Trail Winery and Brewery',
#  'Black Mesa Brewing Company',
#  'Navigation Brewing Co',
#  'Little Harpeth Brewing Co',
#  'De La Vegaâ\x80\x99s Pecan Grill and Brewery',
#  'Sedona Beer Company',
#  'Stony Lake Brewing Company',
#  'Taos Trail Inn Brewery & Steakhouse',
#  'Kirkwood Station Brewing',
#  '아톤브루어리 (Aton Brewery)',
#  'Ozark Beer Company',
#  'Fenceline Beer Lab',
#  'Union Bear Brewing Co.',
#  'Momentum Brewhouse',
#  'Martin House Brewing Company',
#  'Florence Brewing Company',
#  '1850 Brewing Company',
#  'High Perch Brewing Company',
#  'Critz Farms Brewing & Cider Co.',
#  'The Stalking Horse',
#  'River Dog Brewing Co',
#  'Half Acre Beer Co',
#  'Severance Brewing Company',
#  'Teays River Brewing',
#  "Rick Tanner's Grille & Bar/Cherry Street Brewing Cooperative",
#  'Barking Duck Brewing Company',
#  'Bent Kettle Brewing Company',
#  'Bent Bine Brew Co. LLC',
#  'Sarasota Brewing Co',
#  'Hop Nuts Brewing',
#  'Portal Brewing Co',
#  'Milwaukee Brewing Company',
#  'Pints Brewery and Sports Bar',
#  'New Republic Brewing',
#  'Down the Road Brewery',
#  'Cary Ale House',
#  'The Good Beer Company, Inc.',
#  'Forgotten Boardwalk Brewing',
#  'Off the Grid Brewing Co',
#  'Belgian Mare Brewery',
#  'Fossil Fuels Brewing Co',
#  'Pesky Pelican Brewpub',
#  'Dogfish Head Brewings & Eats',
#  'Stadium Pizza Main ST',
#  ...}
